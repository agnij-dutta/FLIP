# %% [markdown]
# # Model Prototyping
# Test XGBoost, neural nets, and ensemble baselines.

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
# TODO: load features/labels and train baseline models.
